# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.0

# %%
import pandas as pd
df = pd.DataFrame({
    "name": ["Sudhir", "Ram", "Hair"], 
    "age": [20, 30, None],
    "gender": ["Male", "Male", "Male"]
})
print(df)
print("------------------------------------")
print(df['age'])

# %%
df['age'] = [40, 50, 60]

# %%
df

# %%
df['age'].max()

# %%
df['age'].min()

# %%
df['age'].mean()

# %%
df.describe()

# %%
df = pd.read_csv('titanic_data.csv')
print(df.shape)
display(df.head())
df.columns

# %%
df[['Age']].min()

# %%
df

# %%
df.dtypes

# %%
df.info()

# %%
df = pd.read_csv('home_data.csv')

# %%
df.shape

# %%
df.info()

# %%
df['date']

# %%
df.dtypes

# %%
df

# %%
# Selecting specific columns 
df.dtypes
df[['view', 'bathrooms']]

# selecting specific rows

# %%
# Selecting specific rows 
br = df[(df['bathrooms'] >4) & (df['bedrooms'] >= 4)]
br

# %%
# finding max, min and mean 
br['bedrooms'].describe()

# %%
# selecting specific columns and rows in one go 
br2 = df.loc[df['bedrooms']==5, ["id", "price", "bedrooms"]]
br2

# %%
df.iloc[2:5, :] = "Jai Shri Ram"
df.head()

# %%
df = pd.read_csv('home_data.csv')

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df.iloc[:, -5:-2]
# Out:
#        zipcode      lat     long
# 0        98178  47.5112 -122.257
# 1        98125  47.7210 -122.319
# 2        98028  47.7379 -122.233
# 3        98136  47.5208 -122.393
# 4        98074  47.6168 -122.045
# ...        ...      ...      ...
# 21608    98103  47.6993 -122.346
# 21609    98146  47.5107 -122.362
# 21610    98144  47.5944 -122.299
# 21611    98027  47.5345 -122.069
# 21612    98144  47.5941 -122.299
#
# [21613 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show()

# %%
df[["id", "price"]].plot()
plt.show()

# %%
df[["id", "price"]].head().plot()
# Out:
# <AxesSubplot:>

# %%
df2 = df[["id", "bedrooms"]].tail()
df2 = df2.set_index('id')
df2
df2.plot()
# Out:
# <AxesSubplot:xlabel='id'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df = df.rename(columns = {"id":"new_id", "sqft_lot15":"square_feet_lot15"})
df.columns
# Out:
# Index(['new_id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'square_feet_lot15'],
#       dtype='object')

# %%
df = df.rename(columns = str.upper)
df.columns
# Out:
# Index(['NEW_ID', 'DATE', 'PRICE', 'BEDROOMS', 'BATHROOMS', 'SQFT_LIVING',
#        'SQFT_LOT', 'FLOORS', 'WATERFRONT', 'VIEW', 'CONDITION', 'GRADE',
#        'SQFT_ABOVE', 'SQFT_BASEMENT', 'YR_BUILT', 'YR_RENOVATED', 'ZIPCODE',
#        'LAT', 'LONG', 'SQFT_LIVING15', 'SQUARE_FEET_LOT15'],
#       dtype='object')

# %%
df["price_in_thousands"] = df["PRICE"]/1000
df = df.rename(columns = str.lower)

# %%
df["rooms"] = df["bedrooms"] + df["bathrooms"]

# %%
abc = (df[["bedrooms", "bathrooms"]].median())

# %%
abc
# Out:
# bedrooms     3.00
# bathrooms    2.25
# dtype: float64

# %%
display(abc)
# Out:
# bedrooms     33.0
# bathrooms     8.0
# dtype: float64

# %%
df[["bedrooms", "bathrooms"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bedrooms   21613 non-null  int64
#  1   bathrooms  21613 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 337.8 KB

# %%
import pandas as pd
df = pd.read_csv('titanic_data.csv')
print(df.shape)
display(df.head())
df.columns
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df.sort_values(by=['Fare','Age'], ascending=[True, False])
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 597          598         0       3                 Johnson, Mr. Alfred
# 263          264         0       1               Harrison, Mr. William
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 179          180         0       3                 Leonard, Mr. Lionel
# ..           ...       ...     ...                                 ...
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
age_sex = df[['Age', 'Sex']]

# %%
age_sex = age_sex.groupby('Sex').sum()
age_sex
# Out:
#              Age
# Sex
# female   7286.00
# male    13919.17

# %%
age_sex.columns
# Out:
# Index(['Age'], dtype='object')

# %%
age_sex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, female to male
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     2 non-null      float64
# dtypes: float64(1)
# memory usage: 32.0+ bytes

# %%
df = pd.read_csv('titanic_data.csv')
print(df.shape)
display(df.head())
df.columns
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.loc[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0:3, 0:3] = 'Sudhir'

# %%
df
# Out:
#     PassengerId Survived  Pclass  \
# 0        Sudhir   Sudhir  Sudhir
# 1        Sudhir   Sudhir  Sudhir
# 2        Sudhir   Sudhir  Sudhir
# 3             4        1       1
# 4             5        0       3
# ..          ...      ...     ...
# 886         887        0       2
# 887         888        1       1
# 888         889        0       3
# 889         890        1       1
# 890         891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Ticket', 'Fare', 'Cabin', 'Embarked']][df['Survived'] > 0]
# Out:
#                Ticket     Fare Cabin Embarked
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 8              347742  11.1333   NaN        S
# 9              237736  30.0708   NaN        C
# ..                ...      ...   ...      ...
# 875              2667   7.2250   NaN        C
# 879             11767  83.1583   C50        C
# 880            230433  26.0000   NaN        S
# 887            112053  30.0000   B42        S
# 889            111369  30.0000  C148        C
#
# [342 rows x 4 columns]
